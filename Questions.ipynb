# %% [markdown]
# ##### Q1.)Zomato Cuisine 1.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# API KEY - 7f51a93a442e47390afafde1af103eaf

import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},params = {'city_id':"1"})

cuisines = r.json()["cuisines"]

for i in cuisines:
    if i["cuisine"]["cuisine_name"] == "Mexican":
        print(i["cuisine"]["cuisine_id"])
# Out:
# 73

# %% [markdown]
# ##### Q2.)Zomato Cuisine 1.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/locations',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {"query" : "Connaught Place"})

ans = r.json()

print(ans["location_suggestions"][0]["entity_type"],ans["location_suggestions"][0]["entity_id"])
# Out:
# subzone 104

# %% [markdown]
# ##### Q3.)Zomato Cuisine 1.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {"entity_type" : "subzone" , "entity_id" : 104,'cuisines' : 73,'sort':'rating','order':'desc','count':10})

ans = r.json()

l = ans["restaurants"]

for i in l:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],i["restaurant"]["R"]["res_id"],end = " ")
    print()
# Out:
# Farzi Cafe 4.5 18233593
# Station Bar 4.5 18851371
# Ministry Of Beer 4.4 18418277
# Lord Of The Drinks 4.4 312603
# Chili's Grill & Bar 4.4 18537536
# Local 4.3 18382360
# Xero Degrees 4.3 18729557
# Warehouse Cafe 4.3 301605
# The Junkyard Cafe 4.3 313256
# Teddy Boy 4.3 18281985

# %% [markdown]
# ##### Q4.)Zomato Cuisine 1.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/categories',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'})

ans = r.json()


for i in ans["categories"]:
    if i["categories"]["name"] == "Cafes":
        print(i["categories"]["id"])
# Out:
# 6

# %% [markdown]
# ##### Q5.)Zomato Cuisine 1.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/categories',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'})

ans = r.json()
cafe_id = 0
for i in ans["categories"]:
    if i["categories"]["name"] == "Cafes":
        cafe_id = i["categories"]["id"]
        break

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {"entity_type" : "subzone" , "entity_id" : 104,'cuisines' : 73,'category':cafe_id,'sort':'rating','order':'desc','count':10})

ans = r.json()

l = ans["restaurants"]

for i in l:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],i["restaurant"]["R"]["res_id"],end = " ")
    print()
# Out:
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.2 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %% [markdown]
# ##### Q.6) Zomato Cuisine 1.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/categories',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'})

ans = r.json()
cafe_id = 0
for i in ans["categories"]:
    if i["categories"]["name"] == "Cafes":
        cafe_id = i["categories"]["id"]
        break

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {"entity_type" : "subzone" , "entity_id" : 104,'cuisines' : 73,'category':cafe_id,'sort':'rating','order':'desc','count':1})

ans = r.json()

res_id = ans["restaurants"][0]["restaurant"]["R"]["res_id"]

r = requests.get('https://developers.zomato.com/api/v2.1/reviews',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {'res_id':res_id , "count":5})

ans = r.json()
for i in range(5):
    review = ans["user_reviews"][i]["review"]
    print(review["user"]["name"] , review["rating"],review["review_text"],end = " ")
    print()
    
# On coding ninjas directly use res_id as parameter to shorten the code to avoid TLE error.
# Out:
# Anshita Sharma 4 This place was cute and little and I personally liked the fries that were the best part of Xero degrees and also the ambience was too good❤️
# ...

# %% [markdown]
# ##### Q7.)Zomato Restaurant 2.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {'entity_type' : 'city','entity_id' : 1,'q':'PA PA YA'})

ans = r.json()

ans = ans["restaurants"][0]["restaurant"]

print(ans["user_rating"]["aggregate_rating"])

print(ans["average_cost_for_two"])

print(ans["cuisines"])

print(ans["location"]["address"])
# Out:
# 4.9
# 2500
# Asian, Chinese, Thai, Japanese
# A-3, Select Citywalk, District Centre, Saket, New Delhi

# %% [markdown]
# ##### Q.8)Zomato Restaurant 2.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {'entity_type' : 'city','entity_id' : 1,'q':'PA PA YA'})

ans = r.json()

ans = ans["restaurants"][0]["restaurant"]

if ans["is_table_reservation_supported"] == 1:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ##### Q.9)Zomato Restaurant 2.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {'entity_type' : 'city','entity_id' : 1,'q':'PA PA YA'})

ans = r.json()

res_id = ans["restaurants"][0]["restaurant"]["R"]["res_id"]

r = requests.get('https://developers.zomato.com/api/v2.1/reviews',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},
                params = {'res_id':res_id})

ans = r.json()

reviews = ans["user_reviews"]

for i in reviews:
    print(i["review"]["user"]["name"] , i["review"]["rating"],i["review"]["review_text"],end=" ")
    print()
# Out:
# Shweta Kumar 4
# Hungry Wolfs 5 This place serves amazing food the ambiance is super good you can go on dates chill out with friends and family kitty’s aswell
# Rushil Badhwar 4
# Anushri Tripathi 5
# TheProud_Glutton 5 The best place to try so many different types of dimsums😋

# %% [markdown]
# # DISTANCE PROBLEMS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Q10.) Zomato distance 3.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

r = requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},params = {'city_id':"1"})

cuisines = r.json()["cuisines"]

for i in cuisines:
    if i["cuisine"]["cuisine_name"] == "BBQ":
        print(i["cuisine"]["cuisine_id"])
# Out:
# 193

# %% [markdown]
# ##### Q11.)Zomato distance 3.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

param={"lat":28.6976709,"lon":77.1384382,"cuisines":"193","sort":"real_distance","oder":"asc","count":10}

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},params = param)


res = r.json()
for i in res["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]['user_rating']["aggregate_rating"],i["restaurant"]["R"]["res_id"],i["restaurant"]["location"]["locality"])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.3 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.4 18889760 Rohini
# Kays Bar-Be-Que 4.0 3079 Ashok Vihar Phase 1
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# The Rowdy Food 0 19501602 Tagore Garden

# %% [markdown]
# ##### Q12.)Zomato distance 3.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

param={"res_id" : 18204820}

r = requests.get('https://developers.zomato.com/api/v2.1/reviews',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},params = param)


res = r.json()

for i in res["user_reviews"]:
    print(i["review"]["user"]["name"],i["review"]["rating"],i["review"]["review_text"])
# Out:
# FoodisBae 4 Roof top cafe with good view. The interiors are nice and the dj plays good music. Loved the food they serve here. They have amazing buffet also. Pizza,pasta and drinks were pretty good.service was nice.
# Milind 4 If u are bored of Barbeque nation , this place is must try for u🤓🔥😅. It is one of the best barbeque restaurants in Delhi offering rooftop seating . So we opted for rooftop seating for our lunch & the view was amazing 🔥😻. We opted for veg buffet which included a range of starters like crispy corn , paneer tikka , spicy mushroom . Then in main course we tried manchurian with noodles . As a complementary drink I ordered Kiwi mojito which was so refreshing & eye catchy too😻🔥🔥🔥🤓🤓. So if u visit Pitampura next time don't miss this amazing place.👻🔥🤓😻😻
# Shashank Agarwal 4 Great place for an experience of grill in north delhi. Great starters, nice main course and average dessert.
# ...

# %% [markdown]
# ##### Q13.)Zomato distance 3.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import json

param={"lat":28.6976709,"lon":77.1384382,"sort":"rating","order":"desc","count":10,"radius":4000}

r = requests.get('https://developers.zomato.com/api/v2.1/search',headers = {'user-key' : '7f51a93a442e47390afafde1af103eaf'},params = param)


res = r.json()

for i in res["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]['user_rating']["aggregate_rating"],i["restaurant"]["R"]["res_id"],i["restaurant"]["location"]["locality"])
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Cafe Lota 4.9 305525 Pragati Maidan
# The Big Chill 4.9 1614 Khan Market
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29

# %% [markdown]
# ##### Q14.)Zomato distance 3.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# no
